# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
df_breach_clean = pd.read_csv('/content/df_breach_clean.csv')
df_breach_clean.head()
# Out:
#                               Name of Covered Entity State  \
# 0                         Brooke Army Medical Center    TX
# 1          Mid America Kidney Stone Association, LLC    MO
# 2    Alaska Department of Health and Social Services    AK
# 3  Health Services for Children with Special Need...    DC
# 4                                  Mark D. Lurie, MD    CA
#
#    Covered Entity Type  Individuals Affected Breach Submission Date  \
# 0  Healthcare Provider                  1000             10/21/2009
# 1  Healthcare Provider                  1000             10/28/2009
# 2  Healthcare Provider                   501             10/30/2009
# 3          Health Plan                  3800             11/17/2009
# 4  Healthcare Provider                  5166             11/20/2009
#
#   Type of Breach         Location of Breached Information  \
# 0          Theft                              Paper/Films
# 1          Theft                           Network Server
# ...

# %%
df_breach_clean.tail()
# Out:
#               Name of Covered Entity State  Covered Entity Type  \
# 1587  Northwest Community Healthcare    IL  Healthcare Provider
# 1588                   Warren Clinic    OK  Healthcare Provider
# 1589               Baxter Healthcare    IL  Healthcare Provider
# 1590    Peabody Retirement Community    IN  Healthcare Provider
# 1591   Gibson Insurance Agency, Inc.    IN   Business Associate
#
#       Individuals Affected Breach Submission Date  \
# 1587                   540              10/7/2016
# 1588                  2938              10/7/2016
# 1589                   992             10/10/2016
# 1590                  1466             10/14/2016
# 1591                  7242             10/14/2016
#
#                       Type of Breach  Location of Breached Information  \
# 1587  Unauthorized Access/Disclosure  Other Portable Electronic Device
# 1588             Hacking/IT Incident                    Network Server
# ...

# %%
df_breach_clean.shape
# Out:
# (1592, 8)

# %%
df_breach_clean.nunique()
# Out:
# Name of Covered Entity              1461
# State                                 52
# Covered Entity Type                    4
# Individuals Affected                1165
# Breach Submission Date              1013
# Type of Breach                        26
# Location of Breached Information      58
# Business Associate Present             2
# dtype: int64

# %%
top_States_affected = df_breach_clean.groupby("State").count().sort_values(by = "Individuals Affected", ascending = False)
top_States_affected
# Out:
#        Name of Covered Entity  Covered Entity Type  Individuals Affected  \
# State
# CA                        188                  188                   188
# TX                        133                  133                   133
# FL                        108                  108                   108
# NY                        100                  100                   100
# IL                         87                   87                    87
# PA                         57                   57                    57
# OH                         54                   54                    54
# IN                         51                   51                    51
# GA                         49                   49                    49
# NC                         41                   41                    41
# MA                         41                   41                    41
# WA                         40                   40                    40
# ...

# %%
top_BreachTYpe = df_breach_clean.groupby("Type of Breach").count().sort_values(by = "Breach Submission Date", ascending = False)
top_BreachTYpe
# Out:
#                                                     Name of Covered Entity  \
# Type of Breach
# Theft                                                                  687
# Unauthorized Access/Disclosure                                         369
# Hacking/IT Incident                                                    210
# Loss                                                                   112
# Other                                                                   76
# Improper Disposal                                                       49
# Theft, Unauthorized Access/Disclosure                                   24
# Loss, Theft                                                             15
# Unknown                                                                  9
# Other, Unauthorized Access/Disclosure                                    7
# Hacking/IT Incident, Unauthorized Access/Disclo...                       7
# ...

# %%
top_CEType= df_breach_clean.groupby("Covered Entity Type").count().sort_values(by = "State", ascending = False)
top_CEType
# Out:
#                            Name of Covered Entity  State  \
# Covered Entity Type
# Healthcare Provider                          1128   1128
# Business Associate                            271    271
# Health Plan                                   189    189
# Healthcare Clearing House                       4      4
#
#                            Individuals Affected  Breach Submission Date  \
# Covered Entity Type
# Healthcare Provider                        1128                    1128
# Business Associate                          271                     271
# Health Plan                                 189                     189
# Healthcare Clearing House                     4                       4
#
#                            Type of Breach  Location of Breached Information  \
# Covered Entity Type
# Healthcare Provider                  1128                              1128
# Business Associate                    271                               271
# ...

# %%
top_LocationBreachedInfo = df_breach_clean.groupby("Location of Breached Information").count().sort_values(by = "State", ascending = False)
top_LocationBreachedInfo
# Out:
#                                                     Name of Covered Entity  \
# Location of Breached Information
# Paper/Films                                                            370
# Laptop                                                                 269
# Network Server                                                         209
# Other                                                                  152
# Desktop Computer                                                       124
# Email                                                                  123
# Other Portable Electronic Device                                        87
# Electronic Medical Record                                               61
# Other, Other Portable Electronic Device                                 43
# Laptop, Other Portable Electronic Device                                16
# Desktop Computer, Network Server                                        13
# ...

# %%
top_BAP = df_breach_clean.groupby("Business Associate Present").count().sort_values(by = "State", ascending = False)
top_BAP
# Out:
#                             Name of Covered Entity  State  \
# Business Associate Present
# No                                            1317   1317
# Yes                                            275    275
#
#                             Covered Entity Type  Individuals Affected  \
# Business Associate Present
# No                                         1317                  1317
# Yes                                         275                   275
#
#                             Breach Submission Date  Type of Breach  \
# Business Associate Present
# No                                            1317            1317
# Yes                                            275             275
#
#                             Location of Breached Information
# Business Associate Present
# No                                                      1317
# Yes                                                      275

# %%
top_BreachSubmiossionDate = df_breach_clean.groupby("Breach Submission Date").count().sort_values(by = "State", ascending = False)
top_BreachSubmiossionDate
# Out:
#                         Name of Covered Entity  State  Covered Entity Type  \
# Breach Submission Date
# 2/26/2016                                    9      9                    9
# 4/2/2015                                     8      8                    8
# 12/6/2013                                    7      7                    7
# 4/25/2014                                    7      7                    7
# 11/29/2012                                   6      6                    6
# ...                                        ...    ...                  ...
# 3/3/2011                                     1      1                    1
# 3/3/2012                                     1      1                    1
# 3/3/2015                                     1      1                    1
# 3/3/2016                                     1      1                    1
# 1/10/2011                                    1      1                    1
#
# ...

# %%
top_10_States_affected = df_breach_clean.groupby("State").count().sort_values(by = "Type of Breach", ascending = False)
top_States_affected
# Out:
#        Name of Covered Entity  Covered Entity Type  Individuals Affected  \
# State
# CA                        188                  188                   188
# TX                        133                  133                   133
# FL                        108                  108                   108
# NY                        100                  100                   100
# IL                         87                   87                    87
# PA                         57                   57                    57
# OH                         54                   54                    54
# IN                         51                   51                    51
# GA                         49                   49                    49
# NC                         41                   41                    41
#
#        Breach Submission Date  Type of Breach  \
# State
# CA                        188             188
# TX                        133             133
# ...

# %%
 #counts Groupby value
df_breach_clean = df_breach_clean.groupby(['State', 'Type_of_Breach', 'IndividualsAffected']
                ).size().unstack(fill_value=0)

# print dataframe

display(df_breach_clean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-692426921219> in <cell line: 2>()
#       1 #counts Groupby value
# ----> 2 df_breach_clean = df_breach_clean.groupby(['State', 'Type_of_Breach', 'IndividualsAffected']
#       3                ).size().unstack(fill_value=0)
#       4
#       5 # print dataframe
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
df_breach_clean.nunique()
# Out:
# Name of Covered Entity              1461
# State                                 52
# Covered Entity Type                    4
# Individuals Affected                1165
# Breach Submission Date              1013
# Type of Breach                        26
# Location of Breached Information      58
# Business Associate Present             2
# dtype: int64

# %%
df_breach_clean.groupby('State').count()
# Out:
#        Name of Covered Entity  Covered Entity Type  Individuals Affected  \
# State
# AK                          6                    6                     6
# AL                         21                   21                    21
# AR                         16                   16                    16
# AZ                         36                   36                    36
# CA                        188                  188                   188
# CO                         29                   29                    29
# CT                         25                   25                    25
# DC                          9                    9                     9
# DE                          2                    2                     2
# FL                        108                  108                   108
# GA                         49                   49                    49
# HI                          2                    2                     2
# ...

# %%
CET= df_breach_clean["Covered Entity Type"].value_counts()[0:4]
CET_labels = df_breach_clean["Covered Entity Type"].unique()[0:4]

with plt.xkcd():
    plt.pie(CET,labels=CET_labels )
    plt.title("Top 4 Covered Entity Type that' reported'")
    plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# ...

# %%
States= df_breach_clean["State"].value_counts()[0:5]
States_labels = df_breach_clean["State"].unique()[0:5]

with plt.xkcd():
    plt.pie(States,labels=States_labels)
    plt.title("Top 5 Sates that 'affected'")
    plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# ...

# %%
df_breach_clean.describe()
# Out:
#        Individuals Affected
# count          1.592000e+03
# mean           1.050907e+05
# std            2.031087e+06
# min            5.000000e+02
# 25%            9.850000e+02
# 50%            2.291500e+03
# 75%            7.470750e+03
# max            7.880000e+07
